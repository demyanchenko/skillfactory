# %%
import pandas as pd
df = pd.read_csv('data_sf.xls')

# %%
small_df = df[df.columns[1:8]].head(25)
small_df
# df.columns[1:8]
# Out:
#                  Name  Age Nationality                 Club      Value  \
# 0            L. Messi   31   Argentina         FC Barcelona  110500000
# 1   Cristiano Ronaldo   33    Portugal             Juventus   77000000
# 2           Neymar Jr   26      Brazil  Paris Saint-Germain  118500000
# 3              De Gea   27       Spain    Manchester United   72000000
# 4        K. De Bruyne   27     Belgium      Manchester City  102000000
# 5           E. Hazard   27     Belgium              Chelsea   93000000
# 6           L. Modrić   32     Croatia          Real Madrid   67000000
# 7           L. Suárez   31     Uruguay         FC Barcelona   80000000
# 8        Sergio Ramos   32       Spain          Real Madrid   51000000
# 9            J. Oblak   25    Slovenia      Atlético Madrid   68000000
# 10     R. Lewandowski   29      Poland    FC Bayern München   77000000
# 11           T. Kroos   28     Germany          Real Madrid   76500000
# ...

# %% [markdown]
# ## В абсолютном выражении

# %%
s = small_df['Nationality'].value_counts()
display(s)
# Out:
# Spain        4
# Uruguay      3
# Belgium      3
# Germany      3
# Argentina    3
# France       2
# Portugal     1
# Slovenia     1
# Croatia      1
# Poland       1
# Brazil       1
# Italy        1
# England      1
# Name: Nationality, dtype: int64

# %%
# Сортировка от большего к меньшему. Первый элемент самый большой
s.index[0]
# Out:
# 'Spain'

# %%
# Посчитать кол-во уникальных значений (национальностей)
len(s.index)
# Out:
# 13

# %%
s['Germany']
# Out:
# 3

# %%
s[s>1]
# Out:
# Spain        4
# Uruguay      3
# Belgium      3
# Germany      3
# Argentina    3
# France       2
# Name: Nationality, dtype: int64

# %%
len(df['Club'].value_counts())
# Out:
# 650

# %%
df['Club'].value_counts().min()
# Out:
# 6

# %% [markdown]
# ## В процентном выражении

# %%
# Параметр normalize=True преобразует счётчики в процентные доли от всей выборки
small_df['Nationality'].value_counts(normalize=True)
# Out:
# Spain        0.16
# Uruguay      0.12
# Belgium      0.12
# Germany      0.12
# Argentina    0.12
# France       0.08
# Portugal     0.04
# Slovenia     0.04
# Croatia      0.04
# Poland       0.04
# Brazil       0.04
# Italy        0.04
# England      0.04
# Name: Nationality, dtype: float64

# %%
s = df['Position'].value_counts(normalize=True)
s[s>0.10]
# Out:
# GK    0.127239
# ST    0.117237
# CB    0.108785
# Name: Position, dtype: float64

# %%
s[s<0.01]
# Out:
# LS     0.009382
# RS     0.008839
# RWB    0.005428
# LWB    0.004652
# CF     0.003954
# LF     0.000620
# LAM    0.000465
# RF     0.000465
# RAM    0.000388
# Name: Position, dtype: float64

# %%
s = df['Wage'].value_counts(bins=4)
display(s)
# Out:
# (435.999, 142000.0]     12818
# (142000.0, 283000.0]       61
# (283000.0, 424000.0]       16
# (424000.0, 565000.0]        2
# Name: Wage, dtype: int64

# %%
s.index[3]
# Out:
# Interval(424000.0, 565000.0, closed='right')

# %%
df[df['Wage']>s.index[3].left]
# Out:
#    Unnamed: 0       Name  Age Nationality          Club      Value    Wage  \
# 0           0   L. Messi   31   Argentina  FC Barcelona  110500000  565000
# 7           7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000
#
#   Position  Crossing  Finishing  ...  Penalties  Composure  Marking  \
# 0       RF        84         95  ...         75         96       33
# 7       RS        77         93  ...         85         85       62
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0              28             26         6          11         15
# 7              45             38        27          25         31
#
#    GKPositioning  GKReflexes
# 0             14           8
# 7             33          37
#
# [2 rows x 42 columns]

# %%
df['Wage'] > s.index[3].left
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12892    False
# 12893    False
# 12894    False
# 12895    False
# 12896    False
# Name: Wage, Length: 12897, dtype: bool

# %%
# В каких пределах находятся худшие 20% показателей точности ударов ногой (FKAccuracy)?
df['FKAccuracy'].value_counts(normalize=True)
# Out:
# 32    0.029619
# 35    0.027991
# 42    0.027526
# 40    0.027371
# 39    0.026595
#         ...
# 90    0.000078
# 93    0.000078
# 94    0.000078
# 92    0.000078
# 91    0.000078
# Name: FKAccuracy, Length: 89, dtype: float64

# %%
# Какие показатели точности ударов ногой демонстрирует большинство футболистов?
df['FKAccuracy'].value_counts(bins=5)
# Out:
# (21.2, 39.4]     4859
# (39.4, 57.6]     3957
# (57.6, 75.8]     2108
# (2.908, 21.2]    1760
# (75.8, 94.0]      213
# Name: FKAccuracy, dtype: int64

# %% [markdown]
# ## .unique() и .nunique()

# %%
small_df['Nationality'].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy'], dtype=object)

# %%
# Количество уникальных значений с помощью len()
len(small_df['Nationality'].unique())
# Out:
# 13

# %%
# Более изящное решение с помощью .nunique()
small_df['Nationality'].nunique()
# Out:
# 13

# %% [markdown]
# ## .reset_index()

# %%
s = small_df['Nationality'].value_counts()
display(s)
# Out:
# Spain        4
# Uruguay      3
# Belgium      3
# Germany      3
# Argentina    3
# France       2
# Portugal     1
# Slovenia     1
# Croatia      1
# Poland       1
# Brazil       1
# Italy        1
# England      1
# Name: Nationality, dtype: int64

# %%
s_df = s.reset_index()
display(s_df)
# Out:
#         index  Nationality
# 0       Spain            4
# 1     Uruguay            3
# 2     Belgium            3
# 3     Germany            3
# 4   Argentina            3
# 5      France            2
# 6    Portugal            1
# 7    Slovenia            1
# 8     Croatia            1
# 9      Poland            1
# 10     Brazil            1
# 11      Italy            1
# 12    England            1

# %%
s_df.columns = ['Nationality', 'Players Count']
display(s_df)
# Out:
#    Nationality  Players Count
# 0        Spain              4
# 1      Uruguay              3
# 2      Belgium              3
# 3      Germany              3
# 4    Argentina              3
# 5       France              2
# 6     Portugal              1
# 7     Slovenia              1
# 8      Croatia              1
# 9       Poland              1
# 10      Brazil              1
# 11       Italy              1
# 12     England              1

# %%
# У какого процента испанских футболистов (Nationality = 'Spain') зарплата (Wage) находится в пределах 25% минимума 
# от наблюдаемого уровня зарплат среди испанских игроков? 
# Ответ дайте в виде целого числа (округлите полученный результат) без знака %
# df[df['Nationality'] == 'Spain'].Wage <= df[df['Nationality'] == 'Spain'].values_counts(bins=4)
s = df[df['Nationality'] == 'Spain'].Wage.value_counts(bins=4).reset_index()
prec_25 = s.loc[0].Wage
count_Spain = df[df['Nationality'] == 'Spain'].Name.count()
int(100*prec_25/count_Spain)
# Out:
# 97

# %%
# Укажите количество уникальных сборных (Nationality), к которым относятся футболисты, 
# выступающие за клуб (Club) "Manchester United".
df[df['Club'] == "Manchester United"].Nationality.nunique()
# Out:
# 13

# %%
# С помощью функции unique определите двух футболистов из Бразилии (Nationality = 'Brazil'), 
# выступающих за клуб (Club) 'Juventus'. 
# Перечислите их имена (Name, как в датафрейме) через запятую в алфавитном порядке.
df[(df['Nationality'] == "Brazil") & (df['Club'] == "Juventus")].Name.unique()
# Out:
# array(['Alex Sandro', 'Douglas Costa'], dtype=object)

# %%
# Укажите, какой из клубов (Club) насчитывает большее количество футболистов возрастом (Age) старше 35 лет.
df[df.Age > 35].Club.value_counts().index[0]
# Out:
# 'Club Atlético Huracán'

# %%
# С помощью функции value_counts с параметром bins разбейте всех футболистов  
# родом из Аргентины (Nationality = 'Argentina') на 4 равные группы по возрасту. 
# Сколько футболистов в возрасте от 34,75 до 41 года в сборной Аргентины?
df[df.Nationality == "Argentina"].Age.value_counts(bins=4).values[3]
# Out:
# 49

# %%
# Сколько процентов футболистов из Испании (Nationality = 'Spain') имеют возраст (Age) 21 год? 
# Введите с точностью до 2 знаков после запятой без указания знака % (например, 12.35).

# Старое решение
round(100 * df[(df.Nationality == 'Spain') & (df.Age == 21)].Age.count() / df[df.Nationality == 'Spain'].Nationality.count(), 2)
# Out:
# 11.77

# %%
# Новое решение через .value_counts(normalize=True)
round(100 * df[df.Nationality == 'Spain'].Age.value_counts(normalize=True)[21], 2)
# Out:
# 11.77

# %% [markdown]
# ## .groupby()

# %%
grouped_df = round(df.groupby(['Club']).mean(), 1)
display(grouped_df)
# Out:
#                        Unnamed: 0   Age      Value    Wage  Crossing  \
# Club
#  SSV Jahn Regensburg       5380.2  25.4   633125.0  3750.0      46.0
# 1. FC Heidenheim 1846      5891.7  23.6   914500.0  3800.0      48.0
# 1. FC Kaiserslautern       7276.1  23.7   486739.1  1434.8      48.1
# 1. FC Köln                 5486.5  22.5  4681000.0  9200.0      44.4
# 1. FC Magdeburg            5558.6  24.5  2739285.7  4000.0      45.1
# ...                           ...   ...        ...     ...       ...
# Zagłębie Sosnowiec         8832.1  26.2   272600.0  1080.0      46.4
# Çaykur Rizespor            5415.3  25.3  1250681.8  5363.6      50.5
# Örebro SK                  8633.3  23.9   325576.9  1384.6      42.8
# Östersunds FK              6805.2  23.9   551500.0  1950.0      47.2
# Śląsk Wrocław              7181.6  26.2   382083.3  2083.3      44.1
#
#                        Finishing  HeadingAccuracy  ShortPassing  Volleys  \
# Club
# ...

# %%
grouped_df.loc['Ajax']['Wage']
# Out:
# 12153.8

# %%
grouped_df = df.groupby('Club')['Wage'].sum().sort_values(ascending=False).head(1)
display(grouped_df)
# Out:
# Club
# Real Madrid    4138000
# Name: Wage, dtype: int64

# %% [markdown]
# ## Задания

# %%
# Отметьте позиции (Position), по которым общая сумма зарплат (Wage) игроков превышает 5 млн евро в год.
df.groupby('Position')['Wage'].sum().sort_values(ascending=False).head(10)
# Out:
# Position
# ST     11873000
# GK      8784000
# CB      7476000
# CM      6194000
# LB      6096000
# CAM     5500000
# LM      5440000
# RM      5098000
# RB      5034000
# CDM     4921000
# Name: Wage, dtype: int64

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean()
# Out:
#                      Wage        Age  ShotPower
# Nationality
# Afghanistan   1250.000000  22.500000  53.750000
# Albania       5931.034483  23.689655  54.551724
# Algeria      15810.810811  27.027027  56.567568
# Andorra       1000.000000  28.000000  58.000000
# Angola        7100.000000  24.700000  63.700000
# ...                   ...        ...        ...
# Uzbekistan    9000.000000  29.500000  71.500000
# Venezuela     6611.111111  23.638889  57.222222
# Wales         9529.411765  24.754902  48.558824
# Zambia        2833.333333  21.833333  66.833333
# Zimbabwe      5000.000000  26.555556  62.888889
#
# [156 rows x 3 columns]

# %%
# сортировка по полю Wage
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean().sort_values(['Wage'],ascending=False).head(10)
# Out:
#                             Wage        Age  ShotPower
# Nationality
# Dominican Republic  71000.000000  23.000000  75.500000
# Egypt               35545.454545  25.818182  59.363636
# Gabon               28900.000000  26.400000  56.900000
# Croatia             26722.222222  24.819444  54.305556
# Equatorial Guinea   25666.666667  28.000000  55.333333
# Belgium             20024.390244  24.030488  56.390244
# Ecuador             18333.333333  24.619048  60.666667
# Uruguay             17590.361446  26.771084  56.192771
# Brazil              17371.158392  27.898345  58.203310
# Algeria             15810.810811  27.027027  56.567568

# %%
# легко вытащить несколько колонок по условию из датафрейма
df.loc[df['Nationality'] == 'Dominican Republic'][['Name','Club','Wage','Age','ShotPower']]
# Out:
#             Name         Club    Wage  Age  ShotPower
# 291      Mariano  Real Madrid  140000   24         85
# 6279  L. Quezada   Córdoba CF    2000   22         66

# %%
# Посчитайте среднюю зарплату (Wage) и цену (Value) игроков разных позиций (Position). 
# Представители какой позиции имеют самую высокую среднюю ценность?
df.groupby('Position')[['Wage','Value']].mean().sort_values(['Value'],ascending=False)
# Out:
#                    Wage         Value
# Position
# LF         75125.000000  2.736250e+07
# RF        119000.000000  2.636583e+07
# LAM        61000.000000  1.324583e+07
# RAM        11800.000000  8.345000e+06
# LS         15421.487603  5.848430e+06
# LCM        13497.854077  4.318090e+06
# RCM        13504.166667  4.217604e+06
# RS         13482.456140  3.645833e+06
# LW         12169.421488  3.603099e+06
# RW         13822.784810  3.495738e+06
# LDM        10243.243243  3.369459e+06
# RCB        11270.334928  3.009055e+06
# CAM         8688.783570  2.963199e+06
# RDM        11282.608696  2.692717e+06
# LCB         9753.056235  2.636516e+06
# LM          7472.527473  2.466174e+06
# ST          7852.513228  2.157252e+06
# RM          6655.352480  2.138734e+06
# LWB         5783.333333  1.931333e+06
# CF          4862.745098  1.848627e+06
# CDM         7121.562952  1.658900e+06
# CM          5805.060918  1.617465e+06
# RWB         6000.000000  1.555571e+06
# ...

# %%
df.groupby(['Nationality'])[['Club','Name']].count()
# Out:
#              Club  Name
# Nationality
# Afghanistan     4     4
# Albania        29    29
# Algeria        37    37
# Andorra         1     1
# Angola         10    10
# ...           ...   ...
# Uzbekistan      2     2
# Venezuela      36    36
# Wales         102   102
# Zambia          6     6
# Zimbabwe        9     9
#
# [156 rows x 2 columns]

# %%
df.groupby(['Club'])['Dribbling'].median()
# Out:
# Club
#  SSV Jahn Regensburg     57.5
# 1. FC Heidenheim 1846    59.5
# 1. FC Kaiserslautern     54.0
# 1. FC Köln               60.5
# 1. FC Magdeburg          53.0
#                          ...
# Zagłębie Sosnowiec       58.0
# Çaykur Rizespor          62.0
# Örebro SK                55.0
# Östersunds FK            61.5
# Śląsk Wrocław            54.5
# Name: Dribbling, Length: 650, dtype: float64

# %%
# Посчитайте среднюю (mean) и медианную (median) зарплату (Wage) футболистов из разных клубов (Club). 
# В скольких клубах средняя и медианная зарплаты совпадают?
stat = df.groupby(['Club'])['Wage'].agg(['mean', 'median'])
# display(stat)
display(stat.loc['Ajax']['mean'])
#.loc['mean'][0]
count_eq = 0 
len(stat)
for index,line in stat.iterrows():
     if line['mean'] == line['median']:
            count_eq += 1
#             print(line)
print(count_eq)
# Out:
# 12153.846153846154
# 52

# %%
# Продолжаем работать с клубами, в которых средняя зарплата совпадает с медианной. 
# Каков максимальный размер средней зарплаты в этой группе клубов?
# Как называется клуб, где игроки получают такую зарплату?

# Создаём новый dataframe только с клубами, где равны средняя зарплата и медиана зарпаты
rows = []
index = []
columns = ['mean','median']
for key,line in stat.iterrows():
     if line['mean'] == line['median']:
            rows.append([line['mean'], line['median']])
            index.append(key)
            count_eq += 1
new_df = pd.DataFrame(rows, index=index, columns=columns)

# Максимальный размер средней зарплаты
new_df[new_df['mean'] == new_df['mean'].max()]
# Out:
#              mean   median
# Cruzeiro  13000.0  13000.0

# %%
# С помощью функции groupby посчитайте сумму зарплат (Wage) футболистов клуба (Club) "Chelsea".
df.groupby(['Club'])[['Wage']].sum().loc['Chelsea']
# Out:
# Wage    2035000
# Name: Chelsea, dtype: int64

# %%
# Определите максимальную зарплату футболиста национальности (Nationality) Аргентина ("Argentina") в возрасте 20 лет.
df[(df['Nationality'] == 'Argentina') & (df['Age'] == 20)].Wage.max()
# Out:
# 54000

# %%
# Определите максимальную зарплату футболиста национальности (Nationality) Аргентина ("Argentina") в возрасте 30 лет.
df[(df['Nationality'] == 'Argentina') & (df['Age'] == 30)].Wage.max()
# Out:
# 300000

# %%
# Определите минимальную зарплату футболиста национальности (Nationality) Аргентина ("Argentina") в возрасте 30 лет.
df[(df['Nationality'] == 'Argentina') & (df['Age'] == 30)].Wage.min()
# Out:
# 1000

# %%
# Определите максимальную силу (Strength) и баланс (Balance) среди игроков клуба (Club) "FC Barcelona" 
# из Аргентины ("Argentina"). Ответ введите через точку с запятой без пробела.
df[(df['Nationality'] == 'Argentina') & (df['Club'] == 'FC Barcelona')][['Strength', 'Balance']]
# Out:
#    Strength  Balance
# 0        59       95

# %% [markdown]
# ## .pivot_table() - cводные таблицы

# %%
'''
values - имя параметра, по которому нам нужно строить сводные данные, применяя агрегирующую функцию сумма.
index - имя колонки, данные которой будут представлены строками сводной таблицы.
columns - имя колонки, которая будет столбцом
aggfunc - имя функций, применяемую к значению
margins - Добавляет строку "Итого" (True / False)
fill_value - значение, которым нужно заполнить все NaN
'''
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(
    values=['Wage'],
    index=['Nationality'],
    columns=['Club'],
    aggfunc='sum',
    margins=True)
display(pivot)
# Out:
#                            Wage                                           \
# Club               FC Barcelona   Juventus Manchester United Real Madrid
# Nationality
# Argentina              565000.0   205000.0          206000.0         NaN
# Belgium                110000.0        NaN          230000.0    240000.0
# Bosnia Herzegovina          NaN   180000.0               NaN         NaN
# Brazil                 465000.0   335000.0           91000.0    570000.0
# Chile                  205000.0        NaN          215000.0         NaN
# Costa Rica                  NaN        NaN               NaN    195000.0
# Croatia                260000.0   160000.0               NaN    420000.0
# Dominican Republic          NaN        NaN               NaN    140000.0
# Ecuador                     NaN        NaN          120000.0         NaN
# England                     NaN        NaN          478000.0         NaN
# France                 495000.0   145000.0          375000.0    459000.0
# ...

# %%
# Сводная таблица, показывающая максимальные зарплаты игроков на разных позициях, играющих за разные клубы, 
# была создана с помощью кода:
df2 = df.pivot_table(columns = 'Position', index = 'Club', values = 'Wage', aggfunc = 'max')

# С помощью какого кода можно получить из этой таблицы информацию о максимальной зарплате вратаря (GK), 
# играющего за футбольный клуб "Manchester City"?
df2.loc['Manchester City']['GK']
# Out:
# 125000.0

# %%
pivot.loc['Belgium']
# Out:
#       Club
# Wage  FC Barcelona         110000.0
#       Juventus                  NaN
#       Manchester United    230000.0
#       Real Madrid          240000.0
#       All                  580000.0
# Name: Belgium, dtype: float64

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Name'],
index=['Nationality'],
columns=['Club'],
aggfunc='count',
fill_value=0)
# display(pivot)
pivot.loc['Argentina']['Name']['Manchester United']
# Out:
# 2

# %% [markdown]
# ## Задания

# %%
# Создайте сводную таблицу, содержащую сведения о количестве игроков, занимающих разные позиции в каждом клубе. 
# Отсутствующие значения замените нулями.
# Каково среднее количество вратарей (GK) в клубе? Ответ округлите до трёх цифр после запятой.
pivot = df.pivot_table(
    values=['Name'],
    index=['Position'],
    columns=['Club'],
    aggfunc='count',
    fill_value=0
)
display(pivot)
# Out:
#                          Name                                             \
# Club      SSV Jahn Regensburg 1. FC Heidenheim 1846 1. FC Kaiserslautern
# Position
# CAM                         0                     1                    0
# CB                          5                     3                    3
# CDM                         1                     0                    3
# CF                          0                     0                    0
# CM                          2                     1                    0
# GK                          3                     2                    3
# LAM                         0                     0                    0
# LB                          2                     2                    2
# LCB                         0                     1                    1
# LCM                         0                     0                    0
# LDM                         1                     0                    0
# ...

# %%
round(pivot.loc['GK'].mean(), 3)
# Out:
# 2.525

# %%
# Используя таблицу, созданную на предыдущем шаге, определите, сколько клубов не содержат данных 
# о центральных полузащитниках. (CM)
# Подсказка: для выполнения этого задания желательно сохранить сводную таблицу в виде отдельного датафрейма 
# и сгруппировать часть данных этого датафрейма с помощью value_counts().
new_pivot = df.pivot_table(
    values=['Name'],
    index=['Club'],
    columns=['Position'],
    aggfunc='count',
    fill_value=0
)
# new_pivot
new_pivot['Name']['CM'].value_counts()[0]
# Out:
# 136

# %%
# С помощью сводной таблицы и функции loc посчитайте, сколько получают ("Wage") русские футболисты ("Russia"), 
# играющие за ФК "AS Monaco".

# С помощью какого кода можно получить из этой таблицы информацию о максимальной зарплате вратаря (GK), 
# играющего за футбольный клуб "Manchester City"?

df.pivot_table(
    values='Wage',
    index='Nationality',
    columns='Club',
    aggfunc='sum',
    fill_value=0
).loc['Russia']['AS Monaco']
# Out:
# 61000

# %%
# Создайте сводную таблицу, содержащую сведения о средней скорости футболистов (SprintSpeed), 
# занимающих разные позиции (Position) в разных футбольных клубах (Club).
# Основываясь на данных таблицы, отметьте три позиции, представители которых в среднем обладают самой высокой скоростью.

# Дополнительно можно ограничить выборку только интересующими нас позициями (из перечня задачи): 
# df.loc[df['Position'].isin(['RB', 'LM', 'RM', 'CF', 'RWM', 'RS'])]
df3 = pd.DataFrame(df.pivot_table(
    values='SprintSpeed',
    index='Club',
    columns='Position',
    aggfunc='mean',
    fill_value=0
))

df3.max().sort_values(ascending=False).head()
# Out:
# Position
# LM    94.0
# RS    94.0
# RM    94.0
# LS    93.0
# RB    93.0
# dtype: float64

# %%
# Используя таблицу, созданную на предыдущем шаге, отметьте названия трёх клубов, 
# в которых центральные форварды (ST) обладают наибольшей средней скоростью.

df3['ST'].sort_values(ascending=False).head(3)
# Out:
# Club
# Vitória      91.0
# Sydney FC    88.0
# CD Lugo      87.0
# Name: ST, dtype: float64
